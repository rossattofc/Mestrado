# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt

# %%
gt64 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\gt64x64.npy')
gt128 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\gt128x128.npy')
predrnnpp1000 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\predrnnpp1000.npy')
predrnnpp8000 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\predrnnpp8000.npy')
predrnnv1 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\predrnnv1.npy')
predrnnv2 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\predrnnv2.npy')
hidden4pp = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\4hiddenpp.npy')
predrnnpp128 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\predrnn128x128.npy')

blackpredrnnpp1000 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\blackpredrnnpp1000.npy')
blackpredrnnv1 = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\blackpredrnnv1.npy')
blackgt = np.load(r'C:\Users\mylar\OneDrive\Área de Trabalho\pred\blacktarget.npy')

# %% [markdown]
# # Teste com imagens normais, sem fundo

# %%
fig, axes = plt.subplots(nrows=6, ncols=10, figsize=(20, 12))
for i in range(10):
    axes[0][i].imshow(gt64[0, i, :, :],cmap="gray")
    axes[1][i].imshow(predrnnpp1000[0, i, :, :],cmap="gray")
    axes[2][i].imshow(predrnnpp8000[0, i+9, :, :, 0],cmap="gray")
    axes[3][i].imshow(predrnnv1[0, i+9, :, :, 0],cmap="gray")
    axes[4][i].imshow(predrnnv2[0, i+9, :, :, 0],cmap="gray")
    axes[5][i].imshow(hidden4pp[0, i+9, :, :, 0],cmap="gray")
    
    axes[0][0].set_title("Ground Truth")
    axes[1][0].set_title("PredRNN++1000")
    axes[2][0].set_title("PredRNN++8000")
    axes[3][0].set_title("PredRNNv1")
    axes[4][0].set_title("PredRNNv2")
    axes[5][0].set_title("PredRNN++ 4 hidden")
    
    fig.tight_layout(pad=1.3)
    
    
    
           
plt.show()

# %%
fig, axes = plt.subplots(nrows=6, ncols=10, figsize=(20, 12))
for i in range(10):
    axes[0][i].imshow(gt64[0, i, :, :],cmap="hsv")
    axes[1][i].imshow(predrnnpp1000[0, i, :, :],cmap="hsv")
    axes[2][i].imshow(predrnnpp8000[0, i+9, :, :, 0],cmap="hsv")
    axes[3][i].imshow(predrnnv1[0, i+9, :, :, 0],cmap="hsv")
    axes[4][i].imshow(predrnnv2[0, i+9, :, :, 0],cmap="hsv")
    axes[5][i].imshow(hidden4pp[0, i+9, :, :, 0],cmap="hsv")
    
    axes[0][0].set_title("Ground Truth")
    axes[1][0].set_title("PredRNN++1000")
    axes[2][0].set_title("PredRNN++8000")
    axes[3][0].set_title("PredRNNv1")
    axes[4][0].set_title("PredRNNv2")
    axes[5][0].set_title("PredRNN++ 4 hidden")
    
    fig.tight_layout(pad=1.3)
    
    
    
           
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
fig, axes = plt.subplots(nrows=6, ncols=10, figsize=(20, 12))
for i in range(10):
    axes[0][i].imshow(gt64[0, i, :, :],cmap="hsv")
    axes[1][i].imshow(predrnnpp1000[0, i, :, :],cmap="hsv", clim=(0.0, 1.0))
    axes[2][i].imshow(predrnnpp8000[0, i+9, :, :, 0],cmap="hsv", clim=(0.0, 1.0))
    axes[3][i].imshow(predrnnv1[0, i+9, :, :, 0],cmap="hsv", clim=(0.0, 1.0))
    axes[4][i].imshow(predrnnv2[0, i+9, :, :, 0],cmap="hsv", clim=(0.0, 1.0))
    axes[5][i].imshow(hidden4pp[0, i+9, :, :, 0],cmap="hsv", clim=(0.0, 1.0))
    
    axes[0][0].set_title("Ground Truth")
    axes[1][0].set_title("PredRNN++1000")
    axes[2][0].set_title("PredRNN++8000")
    axes[3][0].set_title("PredRNNv1")
    axes[4][0].set_title("PredRNNv2")
    axes[5][0].set_title("PredRNN++ 4 hidden")
    
    fig.tight_layout(pad=1.3)
    
    
    
           
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %%
print("Valor máximo Ground Truth: " + str(np.max(gt64)))
print("Valor máximo PredRNN++ 1000 épocas: " + str(np.max(predrnnpp1000)))
print("Valor máximo PredRNN++ 8000 épocas: " + str(np.max(predrnnpp8000)))
print("Valor máximo PredRNNv1: " + str(np.max(predrnnv1)))
print("Valor máximo PredRNNv2: " + str(np.max(predrnnv2)))
print("Valor máximo PredRNN++ 4 hidden: " + str(np.max(hidden4pp)))
# Out:
# Valor máximo Ground Truth: 1.0
# Valor máximo PredRNN++ 1000 épocas: 1.2028643
# Valor máximo PredRNN++ 8000 épocas: 1.235218
# Valor máximo PredRNNv1: 1.1307204
# Valor máximo PredRNNv2: 1.1701065
# Valor máximo PredRNN++ 4 hidden: 1.1405326

# %%
print("Valor mínimo Ground Truth: " + str(np.min(gt64)))
print("Valor mínimo PredRNN++ 1000 épocas: " + str(np.min(predrnnpp1000)))
print("Valor mínimo PredRNN++ 8000 épocas: " + str(np.min(predrnnpp8000)))
print("Valor mínimo PredRNNv1: " + str(np.min(predrnnv1)))
print("Valor mínimo PredRNNv2: " + str(np.min(predrnnv2)))
print("Valor mínimo PredRNN++ 4 hidden: " + str(np.min(hidden4pp)))
# Out:
# Valor mínimo Ground Truth: 0.07058824
# Valor mínimo PredRNN++ 1000 épocas: -0.045241416
# Valor mínimo PredRNN++ 8000 épocas: 0.046930704
# Valor mínimo PredRNNv1: 0.21114887
# Valor mínimo PredRNNv2: 0.11330811
# Valor mínimo PredRNN++ 4 hidden: 0.15961763

# %% [markdown]
# # Teste com imagens 128x128

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, figsize=(20, 12))
for i in range(10):
    axes[0][i].imshow(gt128[0, i, :, :],cmap="hsv")
    axes[1][i].imshow(predrnnpp128[0, i, :, :],cmap="hsv")
    
    
    axes[0][0].set_title("Ground Truth - 128x128")
    axes[1][0].set_title("PredRNN++ - 128x128")
    
    
    fig.tight_layout(pad=1.3)
    
    
    
           
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1440">

# %% [markdown]
# # Teste com imagens de fundo preto

# %%
fig, axes = plt.subplots(nrows=3, ncols=10, figsize=(20, 12))
for i in range(10):
    axes[0][i].imshow(blackgt[0, i, :, :],cmap="gray")
    axes[1][i].imshow(blackpredrnnpp1000[0, i, :, :],cmap="gray")
    axes[2][i].imshow(blackpredrnnv1[0, i+9, :, :, 0],cmap="gray")
   
    axes[0][0].set_title("Ground Truth")
    axes[1][0].set_title("PredRNN++1000")
    axes[2][0].set_title("PredRNNv1")
    
    fig.tight_layout(pad=1.3)
    
    
    
           
plt.show()

# %%
from skimage import data, img_as_float
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error
from skimage import io
from skimage import color

# %%
img = img_as_float(io.imread(r'C:\Users\mylar\OneDrive\Área de Trabalho\predc.jpg'))
img = color.rgb2gray(img)

rows, cols = 260, 256

img_noise = io.imread(r'C:\Users\mylar\OneDrive\Área de Trabalho\gt.jpg')
img_noise = color.rgb2gray(img_noise)

img_const = io.imread(r'C:\Users\mylar\OneDrive\Área de Trabalho\gt.jpg')
img_const = color.rgb2gray(img_const)


fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10, 4),
                         sharex=True, sharey=True)
ax = axes.ravel()

mse_none = mean_squared_error(img, img)
ssim_none = ssim(img, img, data_range=img.max() - img.min())

mse_noise = mean_squared_error(img, img_noise)
ssim_noise = ssim(img, img_noise,
                  data_range=img_noise.max() - img_noise.min())

mse_const = mean_squared_error(img, img_const)
ssim_const = ssim(img, img_const,
                  data_range=img_const.max() - img_const.min())

ax[0].imshow(img, cmap=plt.cm.gray, vmin=0, vmax=1)
ax[0].set_xlabel(f'MSE: {mse_none:.2f}, SSIM: {ssim_none:.2f}')
ax[0].set_title('Original image')

ax[1].imshow(img_noise, cmap=plt.cm.gray, vmin=0, vmax=1)
ax[1].set_xlabel(f'MSE: {mse_noise:.2f}, SSIM: {ssim_noise:.2f}')
ax[1].set_title('Image with noise')

ax[2].imshow(img_const, cmap=plt.cm.gray, vmin=0, vmax=1)
ax[2].set_xlabel(f'MSE: {mse_const:.2f}, SSIM: {ssim_const:.2f}')
ax[2].set_title('Image plus constant')

plt.tight_layout()
plt.show()
